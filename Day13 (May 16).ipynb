# %% [markdown]
# ## PROBLEM SOLVING AND PROGRAMMING
#
#
# ### DAY No-13
# ### DATE- 16TH MAY, 2019

# %% [markdown]
# ## NOTES
#
# ### DAY OBJECTIVES
#
# * Objective 1:File Handilling
#
# * Objective 2:External Libaries
#
# * Objective 3:Functional

# %%
def readfileData(filename):
    f=open(filename,'r')
    filedata=f.readline()
    filedata+=f.readline()
    f.close()
    return filedata

readfileData('DataFiles/data.txt')
# Out:
# 'Data in line 1\nData in line 2\n'

# %%
def readfileData(filename):
    with open(filename,'r') as f:
        for line in f:
            print(line,end='')
    return 
readfileData('DataFiles/data.txt')
# Out:
# Data in line 1
# Data in line 2
# Data in line 3

# %%
def readfileData(filename):
    with open(filename,'r') as f:
        #for line in f:
            #print(line,end='')
        print(f.read())
    return 
readfileData('DataFiles/data.txt')
# Out:
# Data in line 1
# Data in line 2
# Data in line 3

# %%
def writeIntoFile(filename,data):
    with open (filename,'w') as f:
        f.write(data)
    return

writeIntoFile('DataFiles/fileWrite.txt','data written into fileName')

# %%
def writeIntoFile(filename,data,mode):
    with open (filename,'a') as f:
        f.write(data)
    return

writeIntoFile('DataFiles/fileWrite.txt','\nsecond line','a')

# %%
def readfileData(filename):
    li=[]
    with open(filename,'r') as f:
        for line in f:
            li.append(line)
    return li
readfileData('DataFiles/marksData.txt')
# Out:
# ['44\n',
#  '16\n',
#  '71\n',
#  '85\n',
#  '6\n',
#  '15\n',
#  '93\n',
#  '4\n',
#  '12\n',
#  '59\n',
#  '87\n',
#  '72\n',
#  '66\n',
#  '23\n',
#  '50\n',
#  '59\n',
#  '9\n',
#  '4\n',
#  '90\n',
#  '8\n',
#  '27\n',
#  '36\n',
#  '57\n',
#  '27\n',
#  '13\n',
#  '43\n',
#  '63\n',
#  '37\n',
#  '38\n',
#  '39\n',
#  '82\n',
#  '24\n',
#  '67\n',
#  '79\n',
#  '18\n',
#  '0\n',
#  '38\n',
#  '28\n',
#  '38\n',
#  '97\n',
#  '23\n',
#  '99\n',
#  '31\n',
#  '96\n',
#  '27\n',
#  '1\n',
#  '63\n',
#  '92\n',
#  '78\n',
#  '91\n',
#  '52\n',
#  '52\n',
#  '28\n',
#  '55\n',
#  '90\n',
#  '6\n',
#  '67\n',
#  '32\n',
#  '16\n',
#  '48\n',
#  '95\n',
#  '76\n',
#  '95\n',
#  '43\n',
#  '24\n',
#  '61\n',
#  '53\n',
#  '26\n',
#  '38\n',
#  '23\n',
#  '5\n',
#  '5\n',
#  '74\n',
#  '25\n',
#  '34\n',
#  '97\n',
#  '97\n',
#  '82\n',
#  '50\n',
#  '52\n',
#  '40\n',
#  '56\n',
#  '50\n',
#  '80\n',
#  '18\n',
#  '96\n',
#  '41\n',
#  '73\n',
#  '85\n',
#  '87\n',
#  '91\n',
#  '19\n',
#  '1\n',
#  '94\n',
#  '60\n',
#  '13\n',
#  '18\n',
#  '53\n',
#  '54\n',
#  '12\n',
#  '77\n',
#  '94\n',
#  '51\n',
#  '35\n',
#  '99\n',
#  '2\n',
#  '10\n',
#  '47\n',
#  '9\n',
#  '35\n',
#  '70\n',
#  '4\n',
#  '86\n',
#  '78\n',
#  '95\n',
#  '21\n',
#  '64\n',
#  '30\n',
#  '82\n',
#  '73\n',
#  '93\n',
#  '42\n',
#  '87\n',
#  '33\n',
#  '47\n',
#  '73\n',
#  '19\n',
#  '91\n',
#  '79\n',
#  '9\n',
#  '3\n',
#  '68\n',
#  '13\n',
#  '57\n',
#  '8\n',
#  '85\n',
#  '90\n',
#  '70\n',
#  '14\n',
#  '46\n',
#  '19\n',
#  '71\n',
#  '74\n',
#  '71\n',
#  '16\n',
#  '36\n',
#  '88\n',
#  '70\n',
#  '22\n',
#  '35\n',
#  '2\n',
#  '1\n',
#  '55\n',
#  '72\n',
#  '18\n',
#  '40\n',
#  '24\n',
#  '26\n',
#  '62\n',
#  '62\n',
#  '64\n',
#  '98\n',
#  '17\n',
#  '86\n',
#  '41\n',
#  '96\n',
#  '42\n',
#  '7\n',
#  '54\n',
#  '14\n',
#  '99\n',
#  '73\n',
#  '76\n',
#  '41\n',
#  '60\n',
#  '53\n',
#  '72\n',
#  '88\n',
#  '82\n',
#  '86\n',
#  '70\n',
#  '38\n',
#  '69\n',
#  '92\n',
#  '10\n',
#  '72\n',
#  '41\n',
#  '91\n',
#  '87\n',
#  '40\n',
#  '6\n',
#  '0\n',
#  '92\n',
#  '91\n',
#  '26\n',
#  '87\n',
#  '100\n',
#  '87\n',
#  '79\n',
#  '44\n',
#  '60\n',
#  '56\n',
#  '44\n',
#  '18\n',
#  '81\n',
#  '97\n',
#  '39\n',
#  '33\n',
#  '44\n',
#  '49\n',
#  '2\n',
#  '80\n',
#  '37\n',
#  '27\n',
#  '4\n',
#  '12\n',
#  '68\n',
#  '82\n',
#  '95\n',
#  '46\n',
#  '2\n',
#  '84\n',
#  '26\n',
#  '22\n',
#  '100\n',
#  '57\n',
#  '44\n',
#  '58\n',
#  '84\n',
#  '42\n',
#  '51\n',
#  '73\n',
#  '95\n',
#  '50\n',
#  '100\n',
#  '75\n',
#  '92\n',
#  '22\n',
#  '73\n',
#  '28\n',
#  '80\n',
#  '57\n',
#  '36\n',
#  '26\n',
#  '31\n',
#  '81\n',
#  '87\n',
#  '92\n',
#  '6\n',
#  '97\n',
#  '16\n',
#  '36\n',
#  '53\n',
#  '30\n',
#  '40\n',
#  '80\n',
#  '86\n',
#  '0\n',
#  '14\n',
#  '36\n',
#  '58\n',
#  '51\n',
#  '25\n',
#  '92\n',
#  '23\n',
#  '41\n',
#  '43\n',
#  '84\n',
#  '34\n',
#  '33\n',
#  '20\n',
#  '19\n',
#  '60\n',
#  '18\n',
#  '96\n',
#  '55\n',
#  '51\n',
#  '35\n',
#  '64\n',
#  '35\n',
#  '39\n',
#  '75\n',
#  '69\n',
#  '12\n',
#  '3\n',
#  '47\n',
#  '38\n',
#  '31\n',
#  '58\n',
#  '34\n',
#  '17\n',
#  '21\n',
#  '91\n',
#  '32\n',
#  '9\n',
#  '64\n',
#  '78\n',
#  '70\n',
#  '87\n',
#  '59\n',
#  '33\n',
#  '82\n',
#  '57\n',
#  '57\n',
#  '90\n',
#  '95\n',
#  '26\n',
#  '87\n',
#  '52\n',
#  '76\n',
#  '14\n',
#  '74\n',
#  '43\n',
#  '17\n',
#  '21\n',
#  '9\n',
#  '61\n',
#  '62\n',
#  '50\n',
#  '68\n',
#  '38\n',
#  '89\n',
#  '2\n',
#  '99\n',
#  '23\n',
#  '29\n',
#  '52\n',
#  '85\n',
#  '43\n',
#  '74\n',
#  '20\n',
#  '74\n',
#  '53\n',
#  '12\n',
#  '71\n',
#  '48\n',
#  '35\n',
#  '37\n',
#  '10\n',
#  '92\n',
#  '50\n',
#  '36\n',
#  '18\n',
#  '10\n',
#  '11\n',
#  '75\n',
#  '31\n',
#  '30\n',
#  '47\n',
#  '53\n',
#  '1\n',
#  '58\n',
#  '8\n',
#  '88\n',
#  '58\n',
#  '62\n',
#  '70\n',
#  '49\n',
#  '49\n',
#  '14\n',
#  '63\n',
#  '96\n',
#  '86\n',
#  '17\n',
#  '66\n',
#  '59\n',
#  '33\n',
#  '7\n',
#  '95\n',
#  '96\n',
#  '68\n',
#  '11\n',
#  '91\n',
#  '14\n',
#  '4\n',
#  '9\n',
#  '19\n',
#  '42\n',
#  '94\n',
#  '50\n',
#  '15\n',
#  '98\n',
#  '90\n',
#  '0\n',
#  '5\n',
#  '45\n',
#  '29\n',
#  '18\n',
#  '12\n',
#  '23\n',
#  '47\n',
#  '12\n',
#  '76\n',
#  '31\n',
#  '65\n',
#  '19\n',
#  '21\n',
#  '5\n',
#  '56\n',
#  '95\n',
#  '82\n',
#  '18\n',
#  '56\n',
#  '67\n',
#  '57\n',
#  '38\n',
#  '75\n',
#  '98\n',
#  '46\n',
#  '91\n',
#  '64\n',
#  '17\n',
#  '98\n',
#  '48\n',
#  '93\n',
#  '19\n',
#  '20\n',
#  '89\n',
#  '31\n',
#  '63\n',
#  '38\n',
#  '0\n',
#  '69\n',
#  '77\n',
#  '46\n',
#  '57\n',
#  '72\n',
#  '52\n',
#  '64\n',
#  '7\n',
#  '73\n',
#  '98\n',
#  '18\n',
#  '49\n',
#  '54\n',
#  '12\n',
#  '68\n',
#  '60\n',
#  '3\n',
#  '32\n',
#  '20\n',
#  '65\n',
#  '40\n',
#  '60\n',
#  '66\n',
#  '12\n',
#  '24\n',
#  '54\n',
#  '34\n',
#  '49\n',
#  '99\n',
#  '12\n',
#  '10\n',
#  '86\n',
#  '42\n',
#  '16\n',
#  '95\n',
#  '62\n',
#  '9\n',
#  '24\n',
#  '84\n',
#  '42\n',
#  '30\n',
#  '78\n',
#  '28\n',
#  '48\n',
#  '43\n',
#  '84\n',
#  '91\n',
#  '3\n',
#  '61\n',
#  '99\n',
#  '75\n',
#  '3\n',
#  '13\n',
#  '59\n',
#  '9\n',
#  '51\n',
#  '1\n',
#  '24\n',
#  '86\n',
#  '95\n',
#  '25\n',
#  '76\n',
#  '71\n',
#  '94\n',
#  '7\n',
#  '13\n',
#  '29\n',
#  '56\n',
#  '52\n',
#  '64\n',
#  '99\n',
#  '92\n',
#  '46\n',
#  '50\n',
#  '28\n',
#  '50\n',
#  '85\n',
#  '51\n',
#  '28\n',
#  '39\n',
#  '58\n',
#  '8\n',
#  '55\n',
#  '70\n',
#  '49\n',
#  '47\n',
#  '99\n',
#  '68\n',
#  '21\n',
#  '43\n',
#  '79\n',
#  '25\n',
#  '63\n',
#  '4\n',
#  '63\n',
#  '38\n',
#  '23\n',
#  '87\n',
#  '76\n',
#  '49\n',
#  '12\n',
#  '11\n',
#  '34\n',
#  '59\n',
#  '7\n',
#  '96\n',
#  '34\n',
#  '76\n',
#  '58\n',
#  '62\n',
#  '64\n',
#  '31\n',
#  '40\n',
#  '64\n',
#  '7\n',
#  '52\n',
#  '81\n',
#  '67\n',
#  '34\n',
#  '34\n',
#  '67\n',
#  '77\n',
#  '59\n',
#  '95\n',
#  '52\n',
#  '74\n',
#  '49\n',
#  '1\n',
#  '43\n',
#  '62\n',
#  '66\n',
#  '79\n',
#  '3\n',
#  '97\n',
#  '67\n',
#  '66\n',
#  '40\n',
#  '37\n',
#  '33\n',
#  '91\n',
#  '52\n',
#  '67\n',
#  '91\n',
#  '66\n',
#  '51\n',
#  '85\n',
#  '80\n',
#  '0\n',
#  '43\n',
#  '9\n',
#  '57\n',
#  '47\n',
#  '69\n',
#  '74\n',
#  '39\n',
#  '71\n',
#  '66\n',
#  '39\n',
#  '18\n',
#  '47\n',
#  '80\n',
#  '0\n',
#  '90\n',
#  '78\n',
#  '33\n',
#  '26\n',
#  '49\n',
#  '34\n',
#  '6\n',
#  '48\n',
#  '50\n',
#  '10\n',
#  '34\n',
#  '47\n',
#  '62\n',
#  '42\n',
#  '12\n',
#  '37\n',
#  '58\n',
#  '0\n',
#  '89\n',
#  '33\n',
#  '82\n',
#  '90\n',
#  '84\n',
#  '87\n',
#  '57\n',
#  '39\n',
#  '98\n',
#  '73\n',
#  '23\n',
#  '76\n',
#  '61\n',
#  '37\n',
#  '72\n',
#  '51\n',
#  '38\n',
#  '1\n',
#  '68\n',
#  '36\n',
#  '83\n',
#  '34\n',
#  '79\n',
#  '99\n',
#  '80\n',
#  '89\n',
#  '56\n',
#  '36\n',
#  '87\n',
#  '37\n',
#  '57\n',
#  '42\n',
#  '20\n',
#  '31\n',
#  '20\n',
#  '12\n',
#  '2\n',
#  '35\n',
#  '43\n',
#  '98\n',
#  '12\n',
#  '91\n',
#  '9\n',
#  '37\n',
#  '40\n',
#  '64\n',
#  '61\n',
#  '12\n',
#  '36\n',
#  '81\n',
#  '88\n',
#  '84\n',
#  '43\n',
#  '62\n',
#  '20\n',
#  '87\n',
#  '3\n',
#  '72\n',
#  '23\n',
#  '44\n',
#  '34\n',
#  '75\n',
#  '4\n',
#  '27\n',
#  '42\n',
#  '6\n',
#  '31\n',
#  '28\n',
#  '61\n',
#  '2\n',
#  '20\n',
#  '83\n',
#  '38\n',
#  '47\n',
#  '92\n',
#  '85\n',
#  '6\n',
#  '44\n',
#  '38\n',
#  '74\n',
#  '10\n',
#  '22\n',
#  '35\n',
#  '1\n',
#  '23\n',
#  '53\n',
#  '72\n',
#  '2\n',
#  '98\n',
#  '79\n',
#  '32\n',
#  '90\n',
#  '34\n',
#  '18\n',
#  '58\n',
#  '84\n',
#  '50\n',
#  '42\n',
#  '3\n',
#  '23\n',
#  '35\n',
#  '10\n',
#  '17\n',
#  '35\n',
#  '4\n',
#  '22\n',
#  '19\n',
#  '62\n',
#  '73\n',
#  '19\n',
#  '76\n',
#  '73\n',
#  '6\n',
#  '29\n',
#  '49\n',
#  '55\n',
#  '32\n',
#  '51\n',
#  '58\n',
#  '8\n',
#  '77\n',
#  '59\n',
#  '22\n',
#  '82\n',
#  '74\n',
#  '33\n',
#  '11\n',
#  '18\n',
#  '84\n',
#  '13\n',
#  '64\n',
#  '91\n',
#  '57\n',
#  '82\n',
#  '2\n',
#  '95\n',
#  '5\n',
#  '17\n',
#  '60\n',
#  '67\n',
#  '100\n',
#  '78\n',
#  '65\n',
#  '54\n',
#  '40\n',
#  '6\n',
#  '68\n',
#  '58\n',
#  '96\n',
#  '18\n',
#  '50\n',
#  '11\n',
#  '8\n',
#  '98\n',
#  '39\n',
#  '40\n',
#  '77\n',
#  '50\n',
#  '73\n',
#  '57\n',
#  '78\n',
#  '46\n',
#  '66\n',
#  '35\n',
#  '51\n',
#  '72\n',
#  '58\n',
#  '73\n',
#  '81\n',
#  '73\n',
#  '13\n',
#  '37\n',
#  '35\n',
#  '50\n',
#  '79\n',
#  '78\n',
#  '63\n',
#  '94\n',
#  '41\n',
#  '33\n',
#  '36\n',
#  '77\n',
#  '54\n',
#  '17\n',
#  '60\n',
#  '90\n',
#  '11\n',
#  '3\n',
#  '12\n',
#  '28\n',
#  '69\n',
#  '48\n',
#  '22\n',
#  '57\n',
#  '0\n',
#  '41\n',
#  '54\n',
#  '48\n',
#  '18\n',
#  '19\n',
#  '61\n',
#  '9\n',
#  '23\n',
#  '57\n',
#  '66\n',
#  '59\n',
#  '12\n',
#  '23\n',
#  '75\n',
#  '82\n',
#  '0\n',
#  '100\n',
#  '18\n',
#  '94\n',
#  '39\n',
#  '24\n',
#  '41\n',
#  '84\n',
#  '9\n',
#  '43\n',
#  '42\n',
#  '78\n',
#  '10\n',
#  '42\n',
#  '27\n',
#  '83\n',
#  '5\n',
#  '20\n',
#  '21\n',
#  '39\n',
#  '91\n',
#  '8\n',
#  '54\n',
#  '38\n',
#  '9\n',
#  '39\n',
#  '34\n',
#  '34\n',
#  '12\n',
#  '51\n',
#  '44\n',
#  '52\n',
#  '5\n',
#  '43\n',
#  '42\n',
#  '28\n',
#  '88\n',
#  '72\n',
#  '81\n',
#  '26\n',
#  '69\n',
#  '31\n',
#  '13\n',
#  '0\n',
#  '100\n',
#  '79\n',
#  '54\n',
#  '20\n',
#  '91\n',
#  '88\n',
#  '68\n',
#  '92\n',
#  '89\n',
#  '47\n',
#  '29\n',
#  '68\n',
#  '79\n',
#  '37\n',
#  '4\n',
#  '61\n',
#  '95\n',
#  '0\n',
#  '92\n',
#  '30\n',
#  '30\n',
#  '48\n',
#  '52\n',
#  '94\n',
#  '27\n',
#  '91\n',
#  '46\n',
#  '14\n',
#  '23\n',
#  '16\n',
#  '11\n',
#  '39\n',
#  '61\n',
#  '86\n',
#  '25\n',
#  '7\n',
#  '44\n',
#  '75\n',
#  '40\n',
#  '6\n',
#  '73\n',
#  '26\n',
#  '100\n',
#  '71\n',
#  '80\n',
#  '16\n',
#  '99\n',
#  '11\n',
#  '82\n',
#  '59\n',
#  '39\n',
#  '31\n',
#  '52\n',
#  '21\n',
#  '4\n',
#  '99\n',
#  '47\n',
#  '45\n',
#  '48\n',
#  '67\n',
#  '5\n',
#  '60\n',
#  '14\n',
#  '73\n',
#  '36\n',
#  '95\n',
#  '86\n',
#  '78\n',
#  '46\n',
#  '63\n',
#  '98\n',
#  '12\n',
#  '18\n',
#  '94\n',
#  '15\n',
#  '52\n',
#  '64\n',
#  '22\n',
#  '24\n',
#  '4\n',
#  '94\n',
#  '32\n',
#  '95\n',
#  '70\n',
#  '0\n',
#  '69\n',
#  '62\n',
#  '36\n',
#  '56\n',
#  '0\n',
#  '88\n',
#  '44\n',
#  '7\n',
#  '72\n',
#  '84\n',
#  '26\n',
#  '66\n',
#  '81\n',
#  '86\n',
#  '16\n',
#  '76\n',
#  '90\n',
#  '4\n',
#  '0\n',
#  '24\n',
#  '36\n',
#  '18\n',
#  '84\n',
#  '63\n',
#  '96\n',
#  '99\n',
#  '78\n',
#  '75\n',
#  '95\n',
#  '74\n',
#  '61\n',
#  '49\n',
#  '78\n',
#  '31\n',
#  '44\n',
#  '88\n',
#  '14\n',
#  '78\n',
#  '37\n',
#  '58\n',
#  '73\n',
#  '40\n',
#  '24\n',
#  '76\n',
#  '51\n',
#  '1\n',
#  '90\n',
#  '49\n',
#  '18\n',
#  '65\n',
#  '78\n',
#  '0\n',
#  '84\n',
#  '94\n',
#  '84\n',
#  '32\n',
#  '33\n',
#  '99\n',
#  '18\n',
#  ...]

# %% [markdown]
# ### Problem 1:
#
#
# ### Problem Statement: define a function to generate a marks data file for 1300 students such that each marks is entered in a new  line.marks range from 0 to 100 as a ramdom numbers
#
# #### CONSTRAINTS:
#
#
# #### Test cases:
# * Test cases 1
# * Test cases 2
# * Test cases 3

# %%
import random
def generateMarksData(n,filename):
    with open (filename,'w') as marksfile:
        for i in range(0,n):
            marks=random.randint(0,100)
            marksfile.write(str(marks)+'\n')
    return
generateMarksData(1300,'DataFiles\marksData.txt')

# %% [markdown]
# ### method-1

# %%
import timeit 
import numpy as n
def array(filename):
    start=timeit.default_timer()
    x = n.loadtxt(filename)
    print('Higest Mark:', n.max(x))
    print('Lowest Mark:', n.min(x))
    print('Average:', n.average(x))
    return timeit.default_timer()-start
    return
array('DataFiles\marksData.txt')
# Out:
# Higest Mark: 100.0
# Lowest Mark: 0.0
# Average: 49.456153846153846
# 0.011096427000005349

# %% [markdown]
# ### method-2

# %%
import timeit 
def gen(filename):
    start=timeit.default_timer()
    marksdata=readfileData(filename)
    marksdata=list(map(int,marksdata[:len(marksdata)-1]))
    print(type(marksdata[-1]))
    print(timeit.default_timer()-start)
    return marksdata

marksdata=gen('DataFiles\marksData.txt')

def distiction(mark):
    return mark >=80
dis=sum(map(distiction,marksdata))
print(dis)

failed=sum(1 for i in marksdata if i< 40)
print(failed)
# Out:
# <class 'int'>
# 0.006930304999968939
# 271
# 514

# %% [markdown]
# ## external libraries
# * scipy.org
